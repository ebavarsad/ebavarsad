# %% [markdown]
# # COMET FLYBY ANIMATIONS

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# In this notebook, we will graph the motion of a comet traveling through the inner solar system using matplotlib
