# %% [markdown]
# # ADQL Foundations: Querying Astronomical Databases

# %% [markdown]
# ## What You Will Learn in This Notebook
#
# By the end of this notebook, you will be able to:
#
# - Explain what ADQL is and why astronomers use it
# - Write basic ADQL queries using SELECT, FROM, and WHERE
# - Limit results and sort data responsibly
# - Perform simple sky-based searches
# - Download query results into Python for analysis

# %% [markdown]
# ## What Is ADQL?
#
# ADQL (Astronomical Data Query Language) is a SQL-like language designed for astronomical catalogs.
#
# It allows you to:
# - Select specific columns
# - Apply conditions (cuts)
# - Search regions of the sky
# - Avoid downloading millions of useless rows

# %% [markdown]
# ## Connecting to the Gaia Archive
#
# We will use `astroquery` to send ADQL queries to the Gaia archive.

# %%
from astroquery.gaia import Gaia
# Out:
# Status messages could not be retrieved

# %% [markdown]
# ## The Skeleton of an ADQL Query
#
# Every ADQL query follows this basic structure:
#
# - SELECT → what columns you want
# - FROM → which table
# - WHERE → conditions on the data
#
# You must tell the database exactly what you want.
#
# When you prepare to SELECT, you must also denote column names.  In the example below we select the top 10 records from the **gaiadr3.gaia_source** table

# %%
query = """
SELECT TOP 10
    source_id,
    ra,
    dec,
    parallax,
    phot_g_mean_mag
FROM gaiadr3.gaia_source
"""

# %% [markdown]
# ## Running Your First Query
#
# We now send the query to the Gaia archive and retrieve the results.  We define a job to run the query and print them out.

# %%
job = Gaia.launch_job(query)
results = job.get_results()
print(results)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 job = Gaia.launch_job(query)
#       2 results = job.get_results()
#       3 print(results)
#
# File ~/anaconda3/lib/python3.11/site-packages/astroquery/gaia/core.py:963, in GaiaClass.launch_job(self, query, name, output_file, output_format, verbose, dump_to_file, upload_resource, upload_table_name)
#     928 def launch_job(self, query, *, name=None, output_file=None,
#     929                output_format="votable_gzip", verbose=False,
#     930                dump_to_file=False, upload_resource=None,
#     931                upload_table_name=None):
#     932     """Launches a synchronous job
#     933
#     934     Parameters
#    (...)
#     960     A Job object
#     961     """
# --> 963     return TapPlus.launch_job(self, query=query, name=name,
#     964                               output_file=output_file,
#     965                               output_format=output_format,
#     966                               verbose=verbose,
#     967                               dump_to_file=dump_to_file,
#     968                               upload_resource=upload_resource,
#     969                               upload_table_name=upload_table_name,
#     970                               format_with_results_compressed=('votable_gzip',))
#
# File ~/anaconda3/lib/python3.11/site-packages/astroquery/utils/tap/core.py:297, in Tap.launch_job(self, query, name, output_file, output_format, verbose, dump_to_file, upload_resource, upload_table_name, maxrec, format_with_results_compressed)
#     288     response = self.__launchJobMultipart(query=query,
#     289                                          uploadResource=upload_resource,
#     290                                          uploadTableName=upload_table_name,
#    (...)
#     294                                          name=name,
#     295                                          maxrec=maxrec)
#     296 else:
# --> 297     response = self.__launchJob(query=query,
#     298                                 outputFormat=output_format,
#     299                                 context="sync",
#     300                                 verbose=verbose,
#     301                                 name=name,
#     302                                 maxrec=maxrec)
#     303 # handle redirection
#     304 if response.status == 303:
#     305     # redirection
#
# File ~/anaconda3/lib/python3.11/site-packages/astroquery/utils/tap/core.py:651, in Tap.__launchJob(self, query, outputFormat, context, verbose, name, autorun, maxrec)
#     649 if name is not None:
#     650     args['jobname'] = name
# --> 651 response = self.__connHandler.execute_tappost(subcontext=context, data=urlencode(args), verbose=verbose)
#     652 if verbose:
#     653     print(response.status, response.reason)
#
# File ~/anaconda3/lib/python3.11/site-packages/astroquery/utils/tap/conn/tapconn.py:269, in TapConn.execute_tappost(self, subcontext, data, content_type, verbose)
#     248 """Executes a POST request
#     249 The connection is done through HTTP or HTTPS depending on the login
#     250 status (logged in -> HTTPS)
#    (...)
#     266 An HTTP(s) response object
#     267 """
#     268 context = self.__get_tap_context(subcontext)
# --> 269 return self.__execute_post(context, data, content_type, verbose=verbose)
#
# File ~/anaconda3/lib/python3.11/site-packages/astroquery/utils/tap/conn/tapconn.py:422, in TapConn.__execute_post(self, context, data, content_type, verbose)
#     420     print(f"Content-type = {content_type}")
#     421 self.__postHeaders["Content-type"] = content_type
# --> 422 conn.request("POST", context, data, self.__postHeaders)
#     423 response = conn.getresponse()
#     424 self.__currentReason = response.reason
#
# File ~/anaconda3/lib/python3.11/http/client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1283 def request(self, method, url, body=None, headers={}, *,
#    1284             encode_chunked=False):
#    1285     """Send a complete request to the server."""
# -> 1286     self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328 if isinstance(body, str):
#    1329     # RFC 2616 Section 3.7.1 says that text default has a
#    1330     # default charset of iso-8859-1.
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279 else:
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 msg = b"\r\n".join(self._buffer)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#    1046     if hasattr(message_body, 'read'):
#    1047         # Let file-like take precedence over byte-like.  This
#    1048         # is needed to allow the current position of mmap'ed
#    1049         # files to be taken into account.
#
# File ~/anaconda3/lib/python3.11/http/client.py:979, in HTTPConnection.send(self, data)
#     977 if self.sock is None:
#     978     if self.auto_open:
# --> 979         self.connect()
#     980     else:
#     981         raise NotConnected()
#
# File ~/anaconda3/lib/python3.11/http/client.py:1451, in HTTPSConnection.connect(self)
#    1448 def connect(self):
#    1449     "Connect to a host on a given (SSL) port."
# -> 1451     super().connect()
#    1453     if self._tunnel_host:
#    1454         server_hostname = self._tunnel_host
#
# File ~/anaconda3/lib/python3.11/http/client.py:945, in HTTPConnection.connect(self)
#     943 """Connect to the host and port specified in __init__."""
#     944 sys.audit("http.client.connect", self, self.host, self.port)
# --> 945 self.sock = self._create_connection(
#     946     (self.host,self.port), self.timeout, self.source_address)
#     947 # Might fail in OSs that don't implement TCP_NODELAY
#     948 try:
#
# File ~/anaconda3/lib/python3.11/socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     849 try:
#     850     if not all_errors:
# --> 851         raise exceptions[0]
#     852     raise ExceptionGroup("create_connection failed", exceptions)
#     853 finally:
#     854     # Break explicitly a reference cycle
#
# File ~/anaconda3/lib/python3.11/socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     834 if source_address:
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#     838 exceptions.clear()
#
# TimeoutError: [Errno 60] Operation timed out

# %% [markdown]
# We can also put the results into a dataframe from pandas to make analyzing much easier.  We will also output the type for each object so you can see the changes

# %%
import pandas as pd

df = results.to_pandas()

df.head()

type(results)
type(df)

# %% [markdown]
# ## Understanding the Output
#
# The result is an Astropy Table.
# Each row is a star.
# Each column is a measured property.

# %%
results.colnames

# %% [markdown]
# ## Filtering Data with WHERE
#
# The WHERE clause allows you to apply conditions
# so you only retrieve useful data.

# %%
query = """
SELECT TOP 50
    source_id,
    ra,
    dec,
    parallax,
    phot_g_mean_mag
FROM gaiadr3.gaia_source
WHERE parallax > 5
"""

# Run your query here
job = Gaia.launch_job(query)
results = job.get_results()
results

# %% [markdown]
# ## Sorting Results
#
# ORDER BY lets you control how results are sorted.

# %%
query = """
SELECT TOP 20
    source_id,
    parallax,
    phot_g_mean_mag
FROM gaiadr3.gaia_source
WHERE parallax > 5
ORDER BY phot_g_mean_mag ASC
"""

# %% [markdown]
# ## Limiting Results
#
# Never query millions of rows unless you know why.
# Start small. Increase later.

# %% [markdown]
# ## Searching the Sky
#
# Astronomers often search within a region of the sky.
# This is called a cone search.  We use the POINT and CIRCLE to define a circle in the sky to search for stars

# %%
query = """
SELECT TOP 100
    source_id,
    ra,
    dec,
    parallax
FROM gaiadr3.gaia_source
WHERE
    CONTAINS(
        POINT('ICRS', ra, dec),
        CIRCLE('ICRS', 56.75, 24.12, 1.0)
    ) = 1
"""

# %% [markdown]
# ## Exporting Results for Analysis
#
# Querying retrieves data.  Analysis happens in Python.  We will use our pandas dataframe to run analytics on our data

# %%
df.to_csv("gaia_query_results.csv", index=False)

# %% [markdown]
# ## Common Mistakes (Read This)
#
# - Forgetting TOP and crashing the server
# - Requesting columns you don’t understand
# - Assuming parallax = distance
# - Trusting every data point
# - Ignoring units
#
# If a plot looks weird, your query is probably wrong.

# %% [markdown]
# ## Exercises
#
# Modify the queries above to answer the following:
#
# 1. Retrieve 50 stars with parallax > 10 mas
# 2. Sort stars by distance proxy
# 3. Perform a cone search around a location of your choice
# 4. Identify the brightest star in your result
#
# Do not add new columns yet.

# %% [markdown]
# ## What Comes Next
#
# In the next notebook, you will:
# - Learn what Gaia actually measures
# - Apply quality cuts responsibly
# - Build HR diagrams
# - Begin astrophysical interpretation

# %% [markdown]
# ## Exit Ticket
#
# Answer in 2–3 sentences each:
#
# - What does the WHERE clause do?
# - Why is TOP important?
# - Why is querying different from analyzing?
#
# 1.
#
# 2.
#
# 3.
